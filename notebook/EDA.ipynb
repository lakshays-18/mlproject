# %% [markdown]
# # Import libraries and packaages
#
# ## Import numpy, pandas, seaborn, matplotlib, warnings

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Converting CSV data into Pandas DataFrame

# %%
df = pd.read_csv('data/StudentsPerformance.csv')

# %% [markdown]
# ## Displaying the DataFrame first and last 5 rows

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## Information about dataset
#
# - Gender: Male/Female
# - Race/ethnicity: ethnicity of students - Group: A,B,C,D,E
# - Parental level of eduction: final education of the student's parent - bachelors, masters,some college,high school, associate's degree
# - Lunch: having lunch before test(Standard or reduced)
# - Test participation course : complete or not before test
# - Math score
# - Reading score
# - Writing Score

# %% [markdown]
# ## Checking missing values in dataset

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset

# %% [markdown]
# ## Check duplicate values in the dataset

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# No duplicate values present in the dataset

# %% [markdown]
# ## Check the number of data types present in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Check number of unique values in each columns

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# ## Check stats of the data

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Insights
# - mean of the score of the 3 subjects lies between 66.08 to 69.16 and are very close to each other
# - minimum score for maths is 0 i.e a student has score 0,reading is 17, writing is 10
# - standard deviation are also close to each other which ranges between 14.60 to 15.19

# %% [markdown]
# ## Printing unique values from each columns

# %%
columns = df.columns
for col in columns:
    print(f"Column Name - {col}\n Data type - {df[col].dtype}\n unique values - {len(df[col].unique())}:{df[col].unique()}")
# Out:
# Column Name - gender
#  Data type - object
#  unique values - 2:['female' 'male']
# Column Name - race/ethnicity
#  Data type - object
#  unique values - 5:['group B' 'group C' 'group A' 'group D' 'group E']
# Column Name - parental level of education
#  Data type - object
#  unique values - 6:["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Column Name - lunch
#  Data type - object
#  unique values - 2:['standard' 'free/reduced']
# Column Name - test preparation course
#  Data type - object
#  unique values - 2:['none' 'completed']
# Column Name - math score
#  Data type - int64
#  unique values - 81:[ 72  69  90  47  76  71  88  40  64  38  58  65  78  50  18  46  54  66
#   44  74  73  67  70  62  63  56  97  81  75  57  55  53  59  82  77  33
#   52   0  79  39  45  60  61  41  49  30  80  42  27  43  68  85  98  87
#   51  99  84  91  83  89  22 100  96  94  48  35  34  86  92  37  28  24
# ...

# %% [markdown]
# ## Creating new columns Total Score and average

# %%
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df['average'] = df['total_score']/3

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(8,8))
sns.histplot(data=df,x='average',kde=True,bins=10,hue='gender')
plt.show()

# %% [markdown]
# #### Insights
# - Female Students have scored more than male students

# %% [markdown]
# ## Count of how many have scored full marks and less than 20 marks and visualizing it in pie chart

# %%
count_top_marks = []
count_least_marks = []

cols = ['math score','writing score','reading score']
for col in cols:
    count = int(df[df[col]==100]['average'].count())
    count_top_marks.append(count)
    count_less = int(df[df[col]<=20]['average'].count())
    count_least_marks.append(count_less)

# %%
print(count_top_marks)
# Out:
# [7, 14, 17]

# %%
plt.figure(figsize=(5,5))
plt.pie(count_top_marks,labels=['math','writing','reading'],autopct=lambda p: f'{int(p * sum(count_top_marks) / 100)}')
plt.title('Number of students who have scored 100 in respective subjects')
plt.figure(figsize=(5,5))
plt.pie(count_least_marks,labels=['math','writing','reading'],autopct=lambda p: f'{int(p * sum(count_least_marks) / 100)}')
plt.title('Number of students who have scored less than 20 in respective subjects')
plt.show()

# %% [markdown]
# Insights
# - Students scored full marks in:
#    - Maths : 7
#    - Writing : 14
#    - Reading : 17
#
# - Students scored less than < 20 marks in:
#    - Maths : 4
#    - Writing : 3
#    - Reading : 1

# %% [markdown]
# ## Average score of Students based on Ethnicity

# %%
plt.figure(figsize=(8,8))
sns.histplot(data=df,x='average',bins=10,kde=True,hue='race/ethnicity')
plt.title('Average Score based on Ethnicity')
plt.show()

# %% [markdown]
# Insights
# - Group C has the highest average of marks
# - Group A has the lowerst average of marks

# %% [markdown]
# ## Average score based on parental education level

# %%
plt.figure(figsize=(8,8))
sns.histplot(data=df,x='average',kde=True,bins=10,hue='parental level of education')
plt.show()

# %% [markdown]
# Insights
# - master's and bachelor's degree background tend to have high scores
# - high school background has less average compared to others

# %% [markdown]
# ## mean of total score based on test preparation course

# %%
df.groupby('test preparation course')['total_score'].mean().plot(kind='bar')
plt.ylabel('average')
# Out:
# Text(0, 0.5, 'average')

# %% [markdown]
# Insights
# - those have completed the course have scored more marks but those who have not taken the course also scored little bit less compared to those who have completed the course

# %% [markdown]
# ## correlation bewteen the data

# %%
sns.pairplot(df)

# %% [markdown]
# Insights
# - scores of students in reading and writing are little high compared to math and are similar to each other, that is those who have scored good in reading tend to score good in writing
# - students have little low scores in maths
